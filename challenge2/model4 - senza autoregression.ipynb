# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
tfkr = tf.keras.regularizers

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_dir = '../input/dataset/Training.csv'
column_names = ['Sponginess', 'Wonder level', 'Crunchiness', 'Loudness on impact', 'Meme creativity', 'Soap slipperiness','Hype root']

df = pd.read_csv(dataset_dir, header=0, names=column_names)

# Split over users
df_test = df.loc[:6852]
df_train = df.loc[6852:68529]
df_train.shape, df_test.shape
# Out:
# ((61676, 7), (6853, 7))

# %%
test_size = 6853
X_train_raw = df.iloc[:-test_size]
X_test_raw = df.iloc[-test_size:]

# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_test_raw-X_min)/(X_max-X_min)

'''
plt.figure(figsize=(17,5))
plt.plot(X_train_raw.Sponginess, label='Sponginess')
plt.plot(X_test_raw.Sponginess, label='Sponginess')
plt.title('Train-Test Split')
plt.legend()
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(17,5))\nplt.plot(X_train_raw.Sponginess, label='Sponginess')\nplt.plot(X_test_raw.Sponginess, label='Sponginess')\nplt.title('Train-Test Split')\nplt.legend()\nplt.show()\n"

# %%
# Initializing window, stride, validation set size and telescope (direct method)
window = 800
stride = 10
validation_size = 12000
target_labels = df.columns
telescope = 864

# %%
future = df[-window:]
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 800, 7)

# %%
def build_sequences(df, target_labels=target_labels, window=window, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
X_val, y_val = build_sequences(X_test_raw, target_labels, window, stride, telescope)
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((6074, 800, 7), (6074, 864, 7), (554, 800, 7), (554, 864, 7))

# %% [markdown]
# ## Direct Forecasting

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 64
epochs = 200

# %%
# Building the model
def build_CONV_LSTM_model(input_shape, output_shape):

    input_layer = tfkl.Input(shape=input_shape, name='Input')
    convlstm = tfkl.LSTM(64, return_sequences=True, kernel_regularizer=tfkr.l2(1e-4), recurrent_regularizer=tfkr.l2(1e-4), recurrent_dropout=0.2)(input_layer)
    convlstm = tfkl.Dropout(.1)(convlstm)
    convlstm = tfkl.LSTM(128, recurrent_dropout=0.2)(convlstm)
    convlstm = tfkl.Dropout(.1)(convlstm)

    dense = tfkl.Dense(output_shape[-1]*output_shape[-2], activation='relu')(convlstm)
    output_layer = tfkl.Reshape((output_shape[-2],output_shape[-1]))(dense)
    output_layer = tfkl.Conv1D(output_shape[-1], 1, padding='same')(output_layer)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss = tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae', 'mse', tfk.metrics.RootMeanSquaredError()])

    # Return the model
    return model

# %%
model = build_CONV_LSTM_model(input_shape, output_shape)
model.summary()
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2021-12-27 08:22:38.820049: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 800, 7)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 800, 64)           18432
# _________________________________________________________________
# dropout (Dropout)            (None, 800, 64)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               98816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 6048)              780192
# _________________________________________________________________
# reshape (Reshape)            (None, 864, 7)            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 864, 7)            56
# =================================================================
# Total params: 897,496
# Trainable params: 897,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val,y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
                tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)]
).history
# Out:
# 2021-12-27 08:22:39.672551: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 95/95 [==============================] - 454s 5s/step - loss: 0.1010 - mae: 0.2356 - mse: 0.0966 - root_mean_squared_error: 0.3108 - val_loss: 0.0396 - val_mae: 0.1423 - val_mse: 0.0375 - val_root_mean_squared_error: 0.1937
# Epoch 2/200
# 95/95 [==============================] - 450s 5s/step - loss: 0.0342 - mae: 0.1328 - mse: 0.0328 - root_mean_squared_error: 0.1811 - val_loss: 0.0321 - val_mae: 0.1311 - val_mse: 0.0310 - val_root_mean_squared_error: 0.1760
# Epoch 3/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0276 - mae: 0.1220 - mse: 0.0267 - root_mean_squared_error: 0.1635 - val_loss: 0.0279 - val_mae: 0.1244 - val_mse: 0.0272 - val_root_mean_squared_error: 0.1649
# Epoch 4/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0240 - mae: 0.1150 - mse: 0.0233 - root_mean_squared_error: 0.1528 - val_loss: 0.0253 - val_mae: 0.1193 - val_mse: 0.0247 - val_root_mean_squared_error: 0.1572
# Epoch 5/200
# 95/95 [==============================] - 454s 5s/step - loss: 0.0208 - mae: 0.1073 - mse: 0.0203 - root_mean_squared_error: 0.1424 - val_loss: 0.0229 - val_mae: 0.1139 - val_mse: 0.0224 - val_root_mean_squared_error: 0.1497
# Epoch 6/200
# 95/95 [==============================] - 453s 5s/step - loss: 0.0191 - mae: 0.1030 - mse: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 0.0211 - val_mae: 0.1093 - val_mse: 0.0207 - val_root_mean_squared_error: 0.1439
# Epoch 7/200
# 95/95 [==============================] - 456s 5s/step - loss: 0.0184 - mae: 0.1015 - mse: 0.0179 - root_mean_squared_error: 0.1340 - val_loss: 0.0199 - val_mae: 0.1061 - val_mse: 0.0194 - val_root_mean_squared_error: 0.1392
# Epoch 8/200
# 95/95 [==============================] - 454s 5s/step - loss: 0.0169 - mae: 0.0970 - mse: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.0170 - val_mae: 0.0973 - val_mse: 0.0166 - val_root_mean_squared_error: 0.1288
# Epoch 9/200
# 95/95 [==============================] - 452s 5s/step - loss: 0.0158 - mae: 0.0944 - mse: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0169 - val_mae: 0.0971 - val_mse: 0.0165 - val_root_mean_squared_error: 0.1283
# Epoch 10/200
# 95/95 [==============================] - 450s 5s/step - loss: 0.0153 - mae: 0.0927 - mse: 0.0149 - root_mean_squared_error: 0.1219 - val_loss: 0.0161 - val_mae: 0.0963 - val_mse: 0.0157 - val_root_mean_squared_error: 0.1255
# Epoch 11/200
# 95/95 [==============================] - 459s 5s/step - loss: 0.0148 - mae: 0.0914 - mse: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0158 - val_mae: 0.0959 - val_mse: 0.0154 - val_root_mean_squared_error: 0.1241
# Epoch 12/200
# 95/95 [==============================] - 455s 5s/step - loss: 0.0143 - mae: 0.0899 - mse: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0153 - val_mae: 0.0947 - val_mse: 0.0150 - val_root_mean_squared_error: 0.1223
# Epoch 13/200
# 95/95 [==============================] - 449s 5s/step - loss: 0.0156 - mae: 0.0937 - mse: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0158 - val_mae: 0.0956 - val_mse: 0.0154 - val_root_mean_squared_error: 0.1242
# Epoch 14/200
# 95/95 [==============================] - 453s 5s/step - loss: 0.0142 - mae: 0.0897 - mse: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0149 - val_mae: 0.0929 - val_mse: 0.0145 - val_root_mean_squared_error: 0.1206
# Epoch 15/200
# 95/95 [==============================] - 457s 5s/step - loss: 0.0136 - mae: 0.0879 - mse: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0143 - val_mae: 0.0910 - val_mse: 0.0140 - val_root_mean_squared_error: 0.1181
# Epoch 16/200
# 95/95 [==============================] - 456s 5s/step - loss: 0.0132 - mae: 0.0864 - mse: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0141 - val_mae: 0.0925 - val_mse: 0.0138 - val_root_mean_squared_error: 0.1174
# Epoch 17/200
# 95/95 [==============================] - 455s 5s/step - loss: 0.0129 - mae: 0.0855 - mse: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0142 - val_mae: 0.0911 - val_mse: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 18/200
# 95/95 [==============================] - 454s 5s/step - loss: 0.0126 - mae: 0.0846 - mse: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0136 - val_mae: 0.0904 - val_mse: 0.0133 - val_root_mean_squared_error: 0.1155
# Epoch 19/200
# 95/95 [==============================] - 453s 5s/step - loss: 0.0123 - mae: 0.0834 - mse: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0134 - val_mae: 0.0896 - val_mse: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 20/200
# 95/95 [==============================] - 454s 5s/step - loss: 0.0123 - mae: 0.0835 - mse: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0138 - val_mae: 0.0913 - val_mse: 0.0135 - val_root_mean_squared_error: 0.1164
# Epoch 21/200
# 95/95 [==============================] - 453s 5s/step - loss: 0.0122 - mae: 0.0831 - mse: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0129 - val_mae: 0.0879 - val_mse: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 22/200
# 95/95 [==============================] - 452s 5s/step - loss: 0.0120 - mae: 0.0824 - mse: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0135 - val_mae: 0.0895 - val_mse: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 23/200
# 95/95 [==============================] - 457s 5s/step - loss: 0.0118 - mae: 0.0818 - mse: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0132 - val_mae: 0.0887 - val_mse: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 24/200
# 95/95 [==============================] - 455s 5s/step - loss: 0.0117 - mae: 0.0816 - mse: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0134 - val_mae: 0.0898 - val_mse: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 25/200
# 95/95 [==============================] - 450s 5s/step - loss: 0.0115 - mae: 0.0806 - mse: 0.0112 - root_mean_squared_error: 0.1059 - val_loss: 0.0127 - val_mae: 0.0881 - val_mse: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 26/200
# 95/95 [==============================] - 453s 5s/step - loss: 0.0115 - mae: 0.0809 - mse: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0135 - val_mae: 0.0893 - val_mse: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 27/200
# 95/95 [==============================] - 450s 5s/step - loss: 0.0113 - mae: 0.0801 - mse: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0129 - val_mae: 0.0883 - val_mse: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 28/200
# 95/95 [==============================] - 452s 5s/step - loss: 0.0114 - mae: 0.0804 - mse: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0144 - val_mae: 0.0919 - val_mse: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 29/200
# 95/95 [==============================] - 449s 5s/step - loss: 0.0112 - mae: 0.0796 - mse: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0132 - val_mae: 0.0894 - val_mse: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 30/200
# 95/95 [==============================] - 451s 5s/step - loss: 0.0109 - mae: 0.0785 - mse: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0122 - val_mae: 0.0859 - val_mse: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 31/200
# 95/95 [==============================] - 456s 5s/step - loss: 0.0108 - mae: 0.0781 - mse: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0127 - val_mae: 0.0886 - val_mse: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 32/200
# 95/95 [==============================] - 452s 5s/step - loss: 0.0106 - mae: 0.0774 - mse: 0.0104 - root_mean_squared_error: 0.1022 - val_loss: 0.0128 - val_mae: 0.0869 - val_mse: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 33/200
# 95/95 [==============================] - 453s 5s/step - loss: 0.0108 - mae: 0.0778 - mse: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0123 - val_mae: 0.0850 - val_mse: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 34/200
# 95/95 [==============================] - 453s 5s/step - loss: 0.0112 - mae: 0.0790 - mse: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0130 - val_mae: 0.0876 - val_mse: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 35/200
# 95/95 [==============================] - 447s 5s/step - loss: 0.0116 - mae: 0.0801 - mse: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0120 - val_mae: 0.0836 - val_mse: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 36/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0104 - mae: 0.0757 - mse: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0114 - val_mae: 0.0812 - val_mse: 0.0112 - val_root_mean_squared_error: 0.1057
# Epoch 37/200
# 95/95 [==============================] - 449s 5s/step - loss: 0.0100 - mae: 0.0741 - mse: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0113 - val_mae: 0.0814 - val_mse: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 38/200
# 95/95 [==============================] - 447s 5s/step - loss: 0.0097 - mae: 0.0728 - mse: 0.0095 - root_mean_squared_error: 0.0976 - val_loss: 0.0112 - val_mae: 0.0808 - val_mse: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 39/200
# 95/95 [==============================] - 452s 5s/step - loss: 0.0096 - mae: 0.0720 - mse: 0.0094 - root_mean_squared_error: 0.0968 - val_loss: 0.0117 - val_mae: 0.0821 - val_mse: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 40/200
# 95/95 [==============================] - 450s 5s/step - loss: 0.0093 - mae: 0.0709 - mse: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0117 - val_mae: 0.0834 - val_mse: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 41/200
# 95/95 [==============================] - 451s 5s/step - loss: 0.0107 - mae: 0.0764 - mse: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0111 - val_mae: 0.0786 - val_mse: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 42/200
# 95/95 [==============================] - 451s 5s/step - loss: 0.0094 - mae: 0.0710 - mse: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0104 - val_mae: 0.0765 - val_mse: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 43/200
# 95/95 [==============================] - 449s 5s/step - loss: 0.0092 - mae: 0.0702 - mse: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0109 - val_mae: 0.0778 - val_mse: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 44/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0094 - mae: 0.0708 - mse: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0132 - val_mae: 0.0872 - val_mse: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 45/200
# 95/95 [==============================] - 450s 5s/step - loss: 0.0088 - mae: 0.0686 - mse: 0.0086 - root_mean_squared_error: 0.0930 - val_loss: 0.0111 - val_mae: 0.0806 - val_mse: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 46/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0097 - mae: 0.0721 - mse: 0.0095 - root_mean_squared_error: 0.0973 - val_loss: 0.0111 - val_mae: 0.0800 - val_mse: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 47/200
# 95/95 [==============================] - 451s 5s/step - loss: 0.0099 - mae: 0.0729 - mse: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0112 - val_mae: 0.0797 - val_mse: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 48/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0100 - mae: 0.0731 - mse: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0110 - val_mae: 0.0795 - val_mse: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 49/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0092 - mae: 0.0702 - mse: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0123 - val_mae: 0.0842 - val_mse: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 50/200
# 95/95 [==============================] - 449s 5s/step - loss: 0.0089 - mae: 0.0688 - mse: 0.0088 - root_mean_squared_error: 0.0936 - val_loss: 0.0108 - val_mae: 0.0790 - val_mse: 0.0106 - val_root_mean_squared_error: 0.1029
# Epoch 51/200
# 95/95 [==============================] - 448s 5s/step - loss: 0.0087 - mae: 0.0678 - mse: 0.0085 - root_mean_squared_error: 0.0924 - val_loss: 0.0112 - val_mae: 0.0799 - val_mse: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 52/200
# 95/95 [==============================] - 447s 5s/step - loss: 0.0087 - mae: 0.0679 - mse: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0109 - val_mae: 0.0787 - val_mse: 0.0108 - val_root_mean_squared_error: 0.1037

# %%
model.save('trained/DirectForecasting')
# !zip -r DirectForecasting.zip  ./trained/DirectForecasting
# Out:
# 2021-12-27 14:54:09.854982: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
#   adding: trained/DirectForecasting/ (stored 0%)
#   adding: trained/DirectForecasting/assets/ (stored 0%)
#   adding: trained/DirectForecasting/saved_model.pb (deflated 89%)
#   adding: trained/DirectForecasting/keras_metadata.pb (deflated 90%)
#   adding: trained/DirectForecasting/variables/ (stored 0%)
#   adding: trained/DirectForecasting/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: trained/DirectForecasting/variables/variables.index (deflated 66%)

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mse'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mse'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['root_mean_squared_error'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_root_mean_squared_error'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Root Mean Squared Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set 
predictions = model.predict(X_val)

# %%
mean_squared_error = tfk.metrics.mse(y_val.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_val.flatten(),predictions.flatten())
root_mean_squared_error = tfk.metrics.RootMeanSquaredError()
root_mean_squared_error.update_state(y_val.flatten(),predictions.flatten())
print('RMSE: ', root_mean_squared_error.result().numpy())
print('MSE: ', mean_squared_error)
print('MAE: ', mean_absolute_error)
# Out:
# RMSE:  0.10095979
# MSE:  tf.Tensor(0.0101928795, shape=(), dtype=float32)
# MAE:  tf.Tensor(0.076542966, shape=(), dtype=float32)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate_prediction(X_val, y_val, predictions, target_labels, telescope)
