# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
tfkr = tf.keras.regularizers

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_dir = '../input/dataset/Training.csv'
column_names = ['Sponginess', 'Wonder level', 'Crunchiness', 'Loudness on impact', 'Meme creativity', 'Soap slipperiness','Hype root']

df = pd.read_csv(dataset_dir, header=0, names=column_names)

# Split over users
df_test = df.loc[:6852]
df_train = df.loc[6852:68529]
df_train.shape, df_test.shape
# Out:
# ((61676, 7), (6853, 7))

# %%
test_size = 6853
X_train_raw = df.iloc[:-test_size]
X_test_raw = df.iloc[-test_size:]

# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_test_raw-X_min)/(X_max-X_min)

'''
plt.figure(figsize=(17,5))
plt.plot(X_train_raw.Sponginess, label='Sponginess')
plt.plot(X_test_raw.Sponginess, label='Sponginess')
plt.title('Train-Test Split')
plt.legend()
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(17,5))\nplt.plot(X_train_raw.Sponginess, label='Sponginess')\nplt.plot(X_test_raw.Sponginess, label='Sponginess')\nplt.title('Train-Test Split')\nplt.legend()\nplt.show()\n"

# %%
window = 200
stride = 10
target_labels = df.columns
telescope = 1

# %%
future = df[-window:]
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 200, 7)

# %%
def build_sequences(df, target_labels=['sponginess'], window=200, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((6160, 200, 7), (6160, 1, 7), (680, 200, 7), (680, 1, 7))

# %% [markdown]
# # Multivariate Forecasting (Autoregression)

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 64
epochs = 200

# %%
def build_CONV_LSTM_model(input_shape, output_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    convlstm = tfkl.LSTM(64, return_sequences=True, kernel_regularizer=tfkr.l2(1e-4), recurrent_regularizer=tfkr.l2(1e-4), recurrent_dropout=0.2)(input_layer)
    convlstm = tfkl.Dropout(.1)(convlstm)
    convlstm = tfkl.LSTM(128, return_sequences=True, kernel_regularizer=tfkr.l2(1e-4), recurrent_regularizer=tfkr.l2(1e-4), recurrent_dropout=0.2)(convlstm)
    convlstm = tfkl.GlobalAveragePooling1D()(convlstm)
    convlstm = tfkl.Dropout(.1)(convlstm)

    # In order to predict the next values for more than one channel,
    # we can use a Dense layer with a number given by telescope*num_channels,
    # followed by a Reshape layer to obtain a tensor of dimension 
    # [None, telescope, num_channels]
    dense = tfkl.Dense(output_shape[-1]*output_shape[-2], activation='relu')(convlstm)
    output_layer = tfkl.Reshape((output_shape[-2],output_shape[-1]))(dense)
    output_layer = tfkl.Conv1D(output_shape[-1], 1, padding='same')(output_layer)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    # Compile the model
    model.compile(loss = tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae', 'mse', tfk.metrics.RootMeanSquaredError()])

    # Return the model
    return model

# %%
model = build_CONV_LSTM_model(input_shape, output_shape)
model.summary()
#tfk.utils.plot_model(model, expand_nested=True)
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2021-12-21 09:34:50.898015: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 200, 7)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 200, 64)           18432
# _________________________________________________________________
# dropout (Dropout)            (None, 200, 64)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 200, 128)          98816
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 903
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 7)              0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1, 7)              56
# =================================================================
# Total params: 118,207
# Trainable params: 118,207
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# 2021-12-21 09:34:51.446236: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 87/87 [==============================] - 118s 1s/step - loss: 0.1020 - mae: 0.2093 - mse: 0.0795 - root_mean_squared_error: 0.2819 - val_loss: 0.0401 - val_mae: 0.1201 - val_mse: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 2/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0280 - mae: 0.0953 - mse: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0287 - val_mae: 0.1010 - val_mse: 0.0188 - val_root_mean_squared_error: 0.1371
# Epoch 3/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0233 - mae: 0.0924 - mse: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0269 - val_mae: 0.1053 - val_mse: 0.0196 - val_root_mean_squared_error: 0.1400
# Epoch 4/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0209 - mae: 0.0905 - mse: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0248 - val_mae: 0.1030 - val_mse: 0.0189 - val_root_mean_squared_error: 0.1376
# Epoch 5/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0193 - mae: 0.0894 - mse: 0.0140 - root_mean_squared_error: 0.1181 - val_loss: 0.0233 - val_mae: 0.0972 - val_mse: 0.0184 - val_root_mean_squared_error: 0.1356
# Epoch 6/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0179 - mae: 0.0873 - mse: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0226 - val_mae: 0.1013 - val_mse: 0.0184 - val_root_mean_squared_error: 0.1358
# Epoch 7/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0171 - mae: 0.0864 - mse: 0.0133 - root_mean_squared_error: 0.1151 - val_loss: 0.0213 - val_mae: 0.0944 - val_mse: 0.0177 - val_root_mean_squared_error: 0.1332
# Epoch 8/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0163 - mae: 0.0852 - mse: 0.0130 - root_mean_squared_error: 0.1138 - val_loss: 0.0214 - val_mae: 0.0969 - val_mse: 0.0184 - val_root_mean_squared_error: 0.1356
# Epoch 9/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0155 - mae: 0.0837 - mse: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0200 - val_mae: 0.0891 - val_mse: 0.0173 - val_root_mean_squared_error: 0.1314
# Epoch 10/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0150 - mae: 0.0831 - mse: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0195 - val_mae: 0.0929 - val_mse: 0.0171 - val_root_mean_squared_error: 0.1308
# Epoch 11/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0144 - mae: 0.0815 - mse: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0188 - val_mae: 0.0899 - val_mse: 0.0167 - val_root_mean_squared_error: 0.1290
# Epoch 12/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0140 - mae: 0.0807 - mse: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0184 - val_mae: 0.0891 - val_mse: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 13/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0135 - mae: 0.0790 - mse: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0179 - val_mae: 0.0841 - val_mse: 0.0161 - val_root_mean_squared_error: 0.1270
# Epoch 14/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0129 - mae: 0.0768 - mse: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0172 - val_mae: 0.0851 - val_mse: 0.0156 - val_root_mean_squared_error: 0.1247
# Epoch 15/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0124 - mae: 0.0753 - mse: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0167 - val_mae: 0.0814 - val_mse: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 16/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0121 - mae: 0.0745 - mse: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0171 - val_mae: 0.0878 - val_mse: 0.0157 - val_root_mean_squared_error: 0.1254
# Epoch 17/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0118 - mae: 0.0737 - mse: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0164 - val_mae: 0.0832 - val_mse: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 18/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0116 - mae: 0.0732 - mse: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0161 - val_mae: 0.0789 - val_mse: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 19/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0114 - mae: 0.0722 - mse: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0162 - val_mae: 0.0823 - val_mse: 0.0151 - val_root_mean_squared_error: 0.1227
# Epoch 20/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0113 - mae: 0.0724 - mse: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0162 - val_mae: 0.0817 - val_mse: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 21/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0111 - mae: 0.0718 - mse: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0158 - val_mae: 0.0789 - val_mse: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 22/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0110 - mae: 0.0715 - mse: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0156 - val_mae: 0.0798 - val_mse: 0.0146 - val_root_mean_squared_error: 0.1209
# Epoch 23/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0109 - mae: 0.0710 - mse: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0156 - val_mae: 0.0777 - val_mse: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 24/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0109 - mae: 0.0716 - mse: 0.0100 - root_mean_squared_error: 0.0999 - val_loss: 0.0158 - val_mae: 0.0804 - val_mse: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 25/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0109 - mae: 0.0713 - mse: 0.0100 - root_mean_squared_error: 0.0998 - val_loss: 0.0153 - val_mae: 0.0785 - val_mse: 0.0144 - val_root_mean_squared_error: 0.1202
# Epoch 26/200
# 87/87 [==============================] - 109s 1s/step - loss: 0.0106 - mae: 0.0705 - mse: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0156 - val_mae: 0.0825 - val_mse: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 27/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0107 - mae: 0.0709 - mse: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0159 - val_mae: 0.0844 - val_mse: 0.0151 - val_root_mean_squared_error: 0.1227
# Epoch 28/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0106 - mae: 0.0705 - mse: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0150 - val_mae: 0.0781 - val_mse: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 29/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0104 - mae: 0.0701 - mse: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0152 - val_mae: 0.0792 - val_mse: 0.0144 - val_root_mean_squared_error: 0.1201
# Epoch 30/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0104 - mae: 0.0702 - mse: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0149 - val_mae: 0.0775 - val_mse: 0.0142 - val_root_mean_squared_error: 0.1190
# Epoch 31/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0104 - mae: 0.0703 - mse: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0149 - val_mae: 0.0784 - val_mse: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 32/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0103 - mae: 0.0697 - mse: 0.0095 - root_mean_squared_error: 0.0975 - val_loss: 0.0150 - val_mae: 0.0759 - val_mse: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 33/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0103 - mae: 0.0699 - mse: 0.0095 - root_mean_squared_error: 0.0974 - val_loss: 0.0154 - val_mae: 0.0769 - val_mse: 0.0146 - val_root_mean_squared_error: 0.1209
# Epoch 34/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0102 - mae: 0.0695 - mse: 0.0094 - root_mean_squared_error: 0.0972 - val_loss: 0.0144 - val_mae: 0.0791 - val_mse: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 35/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0101 - mae: 0.0689 - mse: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0145 - val_mae: 0.0756 - val_mse: 0.0137 - val_root_mean_squared_error: 0.1170
# Epoch 36/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0100 - mae: 0.0688 - mse: 0.0092 - root_mean_squared_error: 0.0961 - val_loss: 0.0149 - val_mae: 0.0749 - val_mse: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 37/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0099 - mae: 0.0686 - mse: 0.0091 - root_mean_squared_error: 0.0956 - val_loss: 0.0147 - val_mae: 0.0803 - val_mse: 0.0139 - val_root_mean_squared_error: 0.1180
# Epoch 38/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0098 - mae: 0.0679 - mse: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0126 - val_mae: 0.0706 - val_mse: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 39/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0093 - mae: 0.0660 - mse: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0115 - val_mae: 0.0711 - val_mse: 0.0106 - val_root_mean_squared_error: 0.1030
# Epoch 40/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0091 - mae: 0.0657 - mse: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0113 - val_mae: 0.0688 - val_mse: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 41/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0087 - mae: 0.0640 - mse: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0108 - val_mae: 0.0667 - val_mse: 0.0099 - val_root_mean_squared_error: 0.0993
# Epoch 42/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0084 - mae: 0.0629 - mse: 0.0074 - root_mean_squared_error: 0.0860 - val_loss: 0.0108 - val_mae: 0.0682 - val_mse: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 43/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0081 - mae: 0.0618 - mse: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0104 - val_mae: 0.0646 - val_mse: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 44/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0081 - mae: 0.0618 - mse: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0095 - val_mae: 0.0648 - val_mse: 0.0085 - val_root_mean_squared_error: 0.0922
# Epoch 45/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0078 - mae: 0.0600 - mse: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0096 - val_mae: 0.0646 - val_mse: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 46/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0077 - mae: 0.0597 - mse: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0098 - val_mae: 0.0648 - val_mse: 0.0088 - val_root_mean_squared_error: 0.0939
# Epoch 47/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0077 - mae: 0.0598 - mse: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0093 - val_mae: 0.0640 - val_mse: 0.0083 - val_root_mean_squared_error: 0.0911
# Epoch 48/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0075 - mae: 0.0591 - mse: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0096 - val_mae: 0.0631 - val_mse: 0.0086 - val_root_mean_squared_error: 0.0928
# Epoch 49/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0075 - mae: 0.0591 - mse: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0091 - val_mae: 0.0639 - val_mse: 0.0082 - val_root_mean_squared_error: 0.0904
# Epoch 50/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0075 - mae: 0.0591 - mse: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0093 - val_mae: 0.0639 - val_mse: 0.0084 - val_root_mean_squared_error: 0.0915
# Epoch 51/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0074 - mae: 0.0584 - mse: 0.0064 - root_mean_squared_error: 0.0800 - val_loss: 0.0092 - val_mae: 0.0638 - val_mse: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 52/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0075 - mae: 0.0593 - mse: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0092 - val_mae: 0.0631 - val_mse: 0.0082 - val_root_mean_squared_error: 0.0907
# Epoch 53/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0074 - mae: 0.0584 - mse: 0.0064 - root_mean_squared_error: 0.0803 - val_loss: 0.0090 - val_mae: 0.0620 - val_mse: 0.0080 - val_root_mean_squared_error: 0.0897
# Epoch 54/200
# 87/87 [==============================] - 115s 1s/step - loss: 0.0073 - mae: 0.0580 - mse: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0092 - val_mae: 0.0622 - val_mse: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 55/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0072 - mae: 0.0577 - mse: 0.0063 - root_mean_squared_error: 0.0793 - val_loss: 0.0091 - val_mae: 0.0637 - val_mse: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 56/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0073 - mae: 0.0580 - mse: 0.0064 - root_mean_squared_error: 0.0797 - val_loss: 0.0090 - val_mae: 0.0626 - val_mse: 0.0081 - val_root_mean_squared_error: 0.0900
# Epoch 57/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0071 - mae: 0.0574 - mse: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.0089 - val_mae: 0.0620 - val_mse: 0.0079 - val_root_mean_squared_error: 0.0892
# Epoch 58/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0071 - mae: 0.0575 - mse: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0091 - val_mae: 0.0629 - val_mse: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 59/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0074 - mae: 0.0585 - mse: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0094 - val_mae: 0.0655 - val_mse: 0.0085 - val_root_mean_squared_error: 0.0922
# Epoch 60/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0072 - mae: 0.0583 - mse: 0.0063 - root_mean_squared_error: 0.0795 - val_loss: 0.0091 - val_mae: 0.0617 - val_mse: 0.0082 - val_root_mean_squared_error: 0.0908
# Epoch 61/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0071 - mae: 0.0576 - mse: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0096 - val_mae: 0.0629 - val_mse: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 62/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0071 - mae: 0.0575 - mse: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0086 - val_mae: 0.0603 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 63/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0069 - mae: 0.0566 - mse: 0.0061 - root_mean_squared_error: 0.0779 - val_loss: 0.0098 - val_mae: 0.0645 - val_mse: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 64/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0071 - mae: 0.0574 - mse: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0088 - val_mae: 0.0613 - val_mse: 0.0080 - val_root_mean_squared_error: 0.0892
# Epoch 65/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0070 - mae: 0.0573 - mse: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0093 - val_mae: 0.0628 - val_mse: 0.0085 - val_root_mean_squared_error: 0.0919
# Epoch 66/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0071 - mae: 0.0574 - mse: 0.0063 - root_mean_squared_error: 0.0791 - val_loss: 0.0095 - val_mae: 0.0636 - val_mse: 0.0087 - val_root_mean_squared_error: 0.0931
# Epoch 67/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0070 - mae: 0.0571 - mse: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0093 - val_mae: 0.0624 - val_mse: 0.0085 - val_root_mean_squared_error: 0.0922
# Epoch 68/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0067 - mae: 0.0556 - mse: 0.0059 - root_mean_squared_error: 0.0769 - val_loss: 0.0085 - val_mae: 0.0598 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 69/200
# 87/87 [==============================] - 110s 1s/step - loss: 0.0067 - mae: 0.0555 - mse: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0086 - val_mae: 0.0608 - val_mse: 0.0078 - val_root_mean_squared_error: 0.0885
# Epoch 70/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0067 - mae: 0.0557 - mse: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0090 - val_mae: 0.0619 - val_mse: 0.0082 - val_root_mean_squared_error: 0.0904
# Epoch 71/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0067 - mae: 0.0553 - mse: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0092 - val_mae: 0.0616 - val_mse: 0.0084 - val_root_mean_squared_error: 0.0919
# Epoch 72/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0067 - mae: 0.0557 - mse: 0.0059 - root_mean_squared_error: 0.0768 - val_loss: 0.0084 - val_mae: 0.0600 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 73/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0066 - mae: 0.0555 - mse: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0088 - val_mae: 0.0615 - val_mse: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 74/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0068 - mae: 0.0560 - mse: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0088 - val_mae: 0.0617 - val_mse: 0.0081 - val_root_mean_squared_error: 0.0897
# Epoch 75/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0066 - mae: 0.0552 - mse: 0.0058 - root_mean_squared_error: 0.0762 - val_loss: 0.0091 - val_mae: 0.0609 - val_mse: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 76/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0067 - mae: 0.0556 - mse: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0089 - val_mae: 0.0625 - val_mse: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 77/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0067 - mae: 0.0561 - mse: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0086 - val_mae: 0.0611 - val_mse: 0.0078 - val_root_mean_squared_error: 0.0884
# Epoch 78/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0065 - mae: 0.0547 - mse: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0084 - val_mae: 0.0596 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 79/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0065 - mae: 0.0548 - mse: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0089 - val_mae: 0.0617 - val_mse: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 80/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0065 - mae: 0.0547 - mse: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0086 - val_mae: 0.0599 - val_mse: 0.0078 - val_root_mean_squared_error: 0.0883
# Epoch 81/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0065 - mae: 0.0551 - mse: 0.0058 - root_mean_squared_error: 0.0760 - val_loss: 0.0084 - val_mae: 0.0592 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 82/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0065 - mae: 0.0546 - mse: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0086 - val_mae: 0.0597 - val_mse: 0.0078 - val_root_mean_squared_error: 0.0883
# Epoch 83/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0064 - mae: 0.0543 - mse: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0085 - val_mae: 0.0595 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 84/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0064 - mae: 0.0543 - mse: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0083 - val_mae: 0.0592 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0870
# Epoch 85/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0064 - mae: 0.0541 - mse: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0085 - val_mae: 0.0595 - val_mse: 0.0078 - val_root_mean_squared_error: 0.0880
# Epoch 86/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0064 - mae: 0.0541 - mse: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0083 - val_mae: 0.0592 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 87/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0064 - mae: 0.0542 - mse: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0083 - val_mae: 0.0592 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0869
# Epoch 88/200
# 87/87 [==============================] - 112s 1s/step - loss: 0.0064 - mae: 0.0542 - mse: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0085 - val_mae: 0.0607 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 89/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0064 - mae: 0.0543 - mse: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0084 - val_mae: 0.0597 - val_mse: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 90/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0065 - mae: 0.0547 - mse: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0084 - val_mae: 0.0593 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 91/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0064 - mae: 0.0542 - mse: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0084 - val_mae: 0.0591 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 92/200
# 87/87 [==============================] - 115s 1s/step - loss: 0.0064 - mae: 0.0542 - mse: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0084 - val_mae: 0.0594 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 93/200
# 87/87 [==============================] - 120s 1s/step - loss: 0.0063 - mae: 0.0536 - mse: 0.0055 - root_mean_squared_error: 0.0745 - val_loss: 0.0083 - val_mae: 0.0595 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 94/200
# 87/87 [==============================] - 116s 1s/step - loss: 0.0063 - mae: 0.0539 - mse: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0083 - val_mae: 0.0593 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 95/200
# 87/87 [==============================] - 115s 1s/step - loss: 0.0063 - mae: 0.0538 - mse: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0081 - val_mae: 0.0590 - val_mse: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 96/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0063 - mae: 0.0537 - mse: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0082 - val_mae: 0.0590 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 97/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0063 - mae: 0.0539 - mse: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0083 - val_mae: 0.0595 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 98/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0063 - mae: 0.0539 - mse: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0082 - val_mae: 0.0591 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 99/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0063 - mae: 0.0539 - mse: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0083 - val_mae: 0.0594 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 100/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0063 - mae: 0.0538 - mse: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0083 - val_mae: 0.0591 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 101/200
# 87/87 [==============================] - 113s 1s/step - loss: 0.0063 - mae: 0.0537 - mse: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0082 - val_mae: 0.0590 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 102/200
# 87/87 [==============================] - 115s 1s/step - loss: 0.0063 - mae: 0.0537 - mse: 0.0055 - root_mean_squared_error: 0.0744 - val_loss: 0.0082 - val_mae: 0.0588 - val_mse: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 103/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0063 - mae: 0.0538 - mse: 0.0055 - root_mean_squared_error: 0.0745 - val_loss: 0.0082 - val_mae: 0.0587 - val_mse: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 104/200
# 87/87 [==============================] - 114s 1s/step - loss: 0.0063 - mae: 0.0537 - mse: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0083 - val_mae: 0.0592 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 105/200
# 87/87 [==============================] - 111s 1s/step - loss: 0.0063 - mae: 0.0537 - mse: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0083 - val_mae: 0.0591 - val_mse: 0.0076 - val_root_mean_squared_error: 0.0869

# %%
model.save('trained/AutoregressionForecasting')
# !zip -r DirectForecasting.zip  ./trained/AutoregressionForecasting
#model = tfk.models.load_model('DirectForecasting')
# Out:
# 2021-12-21 12:51:21.728429: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
#   adding: trained/AutoregressionForecasting/ (stored 0%)
#   adding: trained/AutoregressionForecasting/variables/ (stored 0%)
#   adding: trained/AutoregressionForecasting/variables/variables.data-00000-of-00001 (deflated 6%)
#   adding: trained/AutoregressionForecasting/variables/variables.index (deflated 67%)
#   adding: trained/AutoregressionForecasting/saved_model.pb (deflated 89%)
#   adding: trained/AutoregressionForecasting/assets/ (stored 0%)
#   adding: trained/AutoregressionForecasting/keras_metadata.pb (deflated 91%)

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mse'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mse'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['root_mean_squared_error'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_root_mean_squared_error'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Root Mean Squared Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set 
predictions = model.predict(X_test)
#print(predictions.shape)

'''
mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
root_mean_squared_error = tfk.metrics.RootMeanSquaredError()
root_mean_squared_error.update_state(y_test.flatten(),predictions.flatten())
print('RMSE: ', root_mean_squared_error.result().numpy())
print('MSE: ', mean_squared_error)
print('MAE: ', mean_absolute_error)
'''
# Out:
# "\nmean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())\nmean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())\nroot_mean_squared_error = tfk.metrics.RootMeanSquaredError()\nroot_mean_squared_error.update_state(y_test.flatten(),predictions.flatten())\nprint('RMSE: ', root_mean_squared_error.result().numpy())\nprint('MSE: ', mean_squared_error)\nprint('MAE: ', mean_absolute_error)\n"

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
#inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, telescope)

# %%
reg_telescope = 864
X_test_reg, y_test_reg = build_sequences(X_test_raw, target_labels, window, stride, reg_telescope)
X_test_reg.shape, y_test_reg.shape
# Out:
# ((594, 200, 7), (594, 864, 7))

# %%
# Autoregressive Forecasting
reg_predictions = np.array([])
X_temp = X_test_reg
for reg in range(0,reg_telescope,telescope):
    pred_temp = model.predict(X_temp)
    if(len(reg_predictions)==0):
        reg_predictions = pred_temp
    else:
        reg_predictions = np.concatenate((reg_predictions,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,telescope:,:],pred_temp), axis=1)

# %%
mean_squared_error = tfk.metrics.mse(y_test_reg.flatten(),reg_predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test_reg.flatten(),reg_predictions.flatten())
root_mean_squared_error = tfk.metrics.RootMeanSquaredError()
root_mean_squared_error.update_state(y_test_reg.flatten(),reg_predictions.flatten())
print('RMSE: ', root_mean_squared_error.result().numpy())
print('MSE: ', mean_squared_error)
print('MAE: ', mean_absolute_error)
# Out:
# RMSE:  0.1051886
# MSE:  tf.Tensor(0.011064642, shape=(), dtype=float32)
# MAE:  tf.Tensor(0.07945405, shape=(), dtype=float32)

# %%
inspect_multivariate_prediction(X_test_reg, y_test_reg, reg_predictions, target_labels, reg_telescope)

# %% [markdown]
# # Predict the future

# %%
maes = []
for i in range(predictions.shape[1]):
    ft_maes = []
    for j in range(predictions.shape[2]):
        ft_maes.append(np.mean(np.abs(y_test[:,i,j]-predictions[:,i,j]), axis=0))
    ft_maes = np.array(ft_maes)
    maes.append(ft_maes)
maes = np.array(maes)

# %%
reg_future = np.array([])
X_temp = future
for reg in range(reg_telescope):
    pred_temp = model.predict(X_temp)
    if(len(reg_future)==0):
        reg_future = pred_temp
    else:
        reg_future = np.concatenate((reg_future,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)

# %%
figs, axs = plt.subplots(len(target_labels), 1, sharex=True, figsize=(17,17))
for i, col in enumerate(target_labels):
    axs[i].plot(np.arange(len(future[0,:,i])), future[0,:,i])
    axs[i].plot(np.arange(len(future[0,:,i]), len(future[0,:,i])+reg_telescope), reg_future[0,:,i], color='orange')
    axs[i].fill_between(
        np.arange(len(future[0,:,i]), len(future[0,:,i])+reg_telescope), 
        reg_future[0,:,i]+maes[:,i], 
        reg_future[0,:,i]-maes[:,i], 
        color='orange', alpha=.3)
    axs[i].set_title(col)
    axs[i].set_ylim(0,1)
plt.show()
